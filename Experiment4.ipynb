# %% [markdown]
# <a href="https://colab.research.google.com/github/ayyddinnnn/S2codebase/blob/main/Experiment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Experiment No.4**
#
# Evaluating divergence and curl of a vector field and visualize

# %% [markdown]
# >**Case:** Find the divergence and curl of the vector field $F=xy \textbf{i}+yz \textbf{j}+zx \textbf{k}$ and plot the vector fields.

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
from sympy.vector import CoordSys3D

# %%
#Define the coordinate system
N= sp.vector.CoordSys3D('N')
#Define the vector field (Example: F = x*y*i + y*z*j + z*x*k)
F = (N.x * N.y)*N.i + (N.y*N.z)*N.j + (N.z*N.x)*N.k
F
# Out:
# N.x*N.y*N.i + N.y*N.z*N.j + N.x*N.z*N.k

# %%
#Compute the divergence
divergence_F = sp.vector.divergence(F)
divergence_F
# Out:
# N.x + N.y + N.z

# %%
#Compute the curl
curl_F = sp.vector.curl(F)
curl_F
# Out:
# (-N.y)*N.i + (-N.z)*N.j + (-N.x)*N.k

# %%
#Define the grid
x =np.linspace(-3,3,10)
y = np.linspace(-3,3,10)
z =np.linspace(-3,3,10)
x,y,z=np.meshgrid(x,y,z)

#initiiazlize arrays to store the vector fields components
U=np.zeros_like(x)
V= np.zeros_like(y)
W np.zeros_like(z)


# initialize
curl_U=np.zeros_like(x)
curl_V= np.zeros_like(y)
curl_W =  np.zeros_like(z)


#Evaluate vector field and curl f at each grid point
for i in range():
