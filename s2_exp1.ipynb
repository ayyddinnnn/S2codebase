# %% [markdown]
# <a href="https://colab.research.google.com/github/ayyddinnnn/S2codebase/blob/main/s2_exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##experiment no 1
# **Introducing python as a tool for computational mathematics**

# %% [markdown]
# ##Aim
#
# To introduce python programming fundamentals and demonstrate its use as a computational tool for basic mathamatical operations releavent to engineering mathematics.

# %% [markdown]
# 1. **Hello World**
# The classic first program for any language

# %%
print("Hello,world!")
# Out:
# Hello,world

# %% [markdown]
# 2. **Basic arithmetic operations**
# Simple operations like addition,substraction,division etc

# %%
#Addition
a=5;b=3
print("a+b=",a + b)

#Substraction
print("a-b=",a - b)

#Multiplication
print("a*b=",a * b)

#Division
print("a/b=",a / b)
# Out:
# a+b= 8
# a-b= 2
# a*b= 15
# a/b= 1.6666666666666667

# %% [markdown]
# **Variablesa and data types**
# Introduction to different data types like integer ,float,strings and complexes

# %%
#iNTEGEAR
X = 10
print("daTA TYPE OF X IS ", type(X))
#FLOAT
y = 8.54
print("daTA TYPE OF y IS ", type(y))
#string
p = "helllo aydin"
print("daTA TYPE OF p IS ", type(p))
#complex
c = 2+3j
print("daTA TYPE OF X IS ", type(c))
# Out:
# daTA TYPE OF X IS  <class 'int'>
# daTA TYPE OF y IS  <class 'float'>
# daTA TYPE OF p IS  <class 'str'>
# daTA TYPE OF X IS  <class 'complex'>

# %% [markdown]
# **Lists**
# creating and manipulating list

# %%
#creating a llist
fruits=["apple","banana","cherry"]
print('list',fruits)
#appending
fruits.append("orange")
print("updatedlist",fruits)
#removing an element
fruits.remove("banana")
print("listafterremoval",fruits)
#inserting an element to specific pos
fruits.insert(0,"banana")
print("newupdatedlist",fruits)
# Out:
# list ['apple', 'banana', 'cherry']
# updatedlist ['apple', 'banana', 'cherry', 'orange']
# listafterremoval ['apple', 'cherry', 'orange']
# newupdatedlist ['banana', 'apple', 'cherry', 'orange']
